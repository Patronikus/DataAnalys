# %%
import requests
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
r = requests.get('https://collectionapi.metmuseum.org/public/collection/v1/search?q=sunflowers')
#id
res = r.json()

# %%
Внимательно посмотрите на формат ответа и сохраните id полученных объектов в список sunflower_ids.

# %%
sunflower_ids = res['objectIDs']

# %%
r_test = requests.get(f'https://collectionapi.metmuseum.org/public/collection/v1/objects/437980')
#инф об id
obj_test = r_test.json()

# %%
obj_test 
dfff
# Out:
# {'objectID': 436524,
#  'isHighlight': False,
#  'accessionNumber': '49.41',
#  'accessionYear': '1949',
#  'isPublicDomain': True,
#  'primaryImage': 'https://images.metmuseum.org/CRDImages/ep/original/DP229743.jpg',
#  'primaryImageSmall': 'https://images.metmuseum.org/CRDImages/ep/web-large/DP229743.jpg',
#  'additionalImages': [],
#  'constituents': [{'constituentID': 161947,
#    'role': 'Artist',
#    'name': 'Vincent van Gogh',
#    'constituentULAN_URL': 'http://vocab.getty.edu/page/ulan/500115588',
#    'constituentWikidata_URL': 'https://www.wikidata.org/wiki/Q5582',
#    'gender': ''}],
#  'department': 'European Paintings',
#  'objectName': 'Painting',
#  'title': 'Sunflowers',
#  'culture': '',
#  'period': '',
#  'dynasty': '',
#  'reign': '',
#  'portfolio': '',
#  'artistRole': 'Artist',
#  'artistPrefix': '',
#  'artistDisplayName': 'Vincent van Gogh',
#  'artistDisplayBio': 'Dutch, Zundert 1853–1890 Auvers-sur-Oise',
#  'artistSuffix': '',
#  'artistAlphaSort': 'Gogh, Vincent van',
#  'artistNationality': 'Dutch',
#  'artistBeginDate': '1853',
#  'artistEndDate': '1890',
#  'artistGender': '',
#  'artistWikidata_URL': 'https://www.wikidata.org/wiki/Q5582',
#  'artistULAN_URL': 'http://vocab.getty.edu/page/ulan/500115588',
#  'objectDate': '1887',
#  'objectBeginDate': 1887,
#  'objectEndDate': 1887,
#  'medium': 'Oil on canvas',
#  'dimensions': '17 x 24 in. (43.2 x 61 cm)',
#  'measurements': [{'elementName': 'Overall',
#    'elementDescription': None,
#    'elementMeasurements': {'Height': 43.2, 'Width': 61}},
#   {'elementName': 'Frame',
#    'elementDescription': None,
#    'elementMeasurements': {'Depth': 6.35,
#     'Height': 66.6751,
#     'Width': 85.0902}}],
#  'creditLine': 'Rogers Fund, 1949',
#  'geographyType': '',
#  'city': '',
#  'state': '',
#  'county': '',
#  'country': '',
#  'region': '',
#  'subregion': '',
#  'locale': '',
#  'locus': '',
#  'excavation': '',
#  'river': '',
#  'classification': 'Paintings',
#  'rightsAndReproduction': '',
#  'linkResource': '',
#  'metadataDate': '2022-06-02T12:28:57.13Z',
#  'repository': 'Metropolitan Museum of Art, New York, NY',
#  'objectURL': 'https://www.metmuseum.org/art/collection/search/436524',
#  'tags': [{'term': 'Still Life',
#    'AAT_URL': 'http://vocab.getty.edu/page/aat/300015638',
#    'Wikidata_URL': 'https://www.wikidata.org/wiki/Q170571'},
#   {'term': 'Sunflowers',
#    'AAT_URL': 'http://vocab.getty.edu/page/aat/300404749',
#    'Wikidata_URL': 'https://www.wikidata.org/wiki/Q171497'}],
#  'objectWikidata_URL': 'https://www.wikidata.org/wiki/Q9213165',
#  'isTimelineWork': False,
#  'GalleryNumber': '825'}

# %%
dfff = pd.DataFrame.from_dict(obj_test, orient='index')

# %%
dfff
# Out:
#                                                                        0
# objectID                                                          436524
# isHighlight                                                        False
# accessionNumber                                                    49.41
# accessionYear                                                       1949
# isPublicDomain                                                      True
# primaryImage           https://images.metmuseum.org/CRDImages/ep/orig...
# primaryImageSmall      https://images.metmuseum.org/CRDImages/ep/web-...
# additionalImages                                                      []
# constituents           [{'constituentID': 161947, 'role': 'Artist', '...
# department                                            European Paintings
# objectName                                                      Painting
# title                                                         Sunflowers
# culture
# period
# dynasty
# reign
# portfolio
# artistRole                                                        Artist
# artistPrefix
# artistDisplayName                                       Vincent van Gogh
# artistDisplayBio                Dutch, Zundert 1853–1890 Auvers-sur-Oise
# artistSuffix
# artistAlphaSort                                        Gogh, Vincent van
# artistNationality                                                  Dutch
# artistBeginDate                                                     1853
# artistEndDate                                                       1890
# artistGender
# artistWikidata_URL                   https://www.wikidata.org/wiki/Q5582
# artistULAN_URL                http://vocab.getty.edu/page/ulan/500115588
# objectDate                                                          1887
# objectBeginDate                                                     1887
# objectEndDate                                                       1887
# medium                                                     Oil on canvas
# dimensions                                    17 x 24 in. (43.2 x 61 cm)
# measurements           [{'elementName': 'Overall', 'elementDescriptio...
# creditLine                                             Rogers Fund, 1949
# geographyType
# city
# state
# county
# country
# region
# subregion
# locale
# locus
# excavation
# river
# classification                                                 Paintings
# rightsAndReproduction
# linkResource
# metadataDate                                     2022-06-02T12:28:57.13Z
# repository                      Metropolitan Museum of Art, New York, NY
# objectURL              https://www.metmuseum.org/art/collection/searc...
# tags                   [{'term': 'Still Life', 'AAT_URL': 'http://voc...
# objectWikidata_URL                https://www.wikidata.org/wiki/Q9213165
# isTimelineWork                                                     False
# GalleryNumber                                                        825

# %% [markdown]
# Теперь напишите цикл, с помощью которого будет собрана информация об объектах, которые были получены на 2 шаге.

# %%
df = pd.DataFrame()
for i in sunflower_ids:
    r_test = requests.get(f'https://collectionapi.metmuseum.org/public/collection/v1/objects/{i}')
    obj_test = r_test.json()
    df = df.append(obj_test, ignore_index = True)

# %%
df.query("culture == 'Japan'")
# Out:
#    GalleryNumber accessionNumber accessionYear additionalImages  \
# 29                 14.40.827a, b          1914               []
#
#    artistAlphaSort artistBeginDate artistDisplayBio artistDisplayName  \
# 29
#
#    artistEndDate artistGender  ... region reign  \
# 29                             ...
#
#                                   repository rightsAndReproduction river  \
# 29  Metropolitan Museum of Art, New York, NY
#
#    state subregion                                               tags  \
# 29                  [{'term': 'Sunflowers', 'AAT_URL': 'http://voc...
#
#           title message
# 29  Incense box     NaN
#
# [1 rows x 58 columns]

# %% [markdown]
# Теперь попробуем построить более сложный запрос с помощью секции "Search"! На этот раз параметры необходимо передать через "&", например, departmentId (id департамента – 1) и q (ключевое слово – cat):
#
# r = requests.get('https://collectionapi.metmuseum.org/public/collection/v1/search?departmentId=1&q=cat')
# cats = r.json()
#
# Выполните поисковый запрос для департамента "Asian art" (departmentId = 6) с тегом "cat" и запишите id объектов в cat_ids. Используйте цикл из шага 4, чтобы получить данные о первой 1000 объектов из списка.
#
# Note: выполнение цикла может занять некоторое время (~5 минут), поэтому проверять его работоспособность лучше на более маленькой выборке!
#
# В качестве ответа укажите, в каком периоде (period) было выполнено наибольшее количество работ, представленных в музее?

# %%
r = requests.get('https://collectionapi.metmuseum.org/public/collection/v1/search?departmentId=6&q=cat')
cats = r.json()

# %%
cats_ids = cats['objectIDs']

# %%
cats_ids[2]
# Out:
# 53222

# %%
rr_test = requests.get('https://collectionapi.metmuseum.org/public/collection/v1/objects/53222')
objj_test = rr_test.json()

# %%
dff = pd.DataFrame()
for i in cats_ids:
    rr_test = requests.get(f'https://collectionapi.metmuseum.org/public/collection/v1/objects/{i}')
    objj_test = rr_test.json()
    dff = dff.append(objj_test, ignore_index = True)

# %%
dff.period.value_counts()
# Out:
# Edo period (1615–1868)                       1201
#                                               311
# Ming dynasty (1368–1644)                      186
# Qing dynasty (1644–1911)                      146
# Muromachi period (1392–1573)                   94
#                                              ...
# Eastern Wei dynasty (534–550)                   1
# Meiji period (1866–1912)                        1
# Yuan (1271–1368)–Ming dynasty (1368–1644)       1
# Early Malla period                              1
# Nayaka period                                   1
# Name: period, Length: 186, dtype: int64
