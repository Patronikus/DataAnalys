# %%
pip install google-api-python-client google-auth-httplib2 google-auth-oauthlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: google-api-python-client in /mnt/HC_Volume_18315164/home-jupyter/jupyter-p-rudenko/.local/lib/python3.7/site-packages (2.49.0)
# Requirement already satisfied: google-auth-httplib2 in /mnt/HC_Volume_18315164/home-jupyter/jupyter-p-rudenko/.local/lib/python3.7/site-packages (0.1.0)
# Requirement already satisfied: google-auth-oauthlib in /mnt/HC_Volume_18315164/home-jupyter/jupyter-p-rudenko/.local/lib/python3.7/site-packages (0.5.1)
# Requirement already satisfied: google-auth<3.0.0dev,>=1.16.0 in /mnt/HC_Volume_18315164/home-jupyter/jupyter-p-rudenko/.local/lib/python3.7/site-packages (from google-api-python-client) (2.6.6)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /opt/tljh/user/lib/python3.7/site-packages (from google-api-python-client) (3.0.1)
# Requirement already satisfied: httplib2<1dev,>=0.15.0 in /opt/tljh/user/lib/python3.7/site-packages (from google-api-python-client) (0.18.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /mnt/HC_Volume_18315164/home-jupyter/jupyter-p-rudenko/.local/lib/python3.7/site-packages (from google-api-python-client) (2.8.1)
# Requirement already satisfied: six in /opt/tljh/user/lib/python3.7/site-packages (from google-auth-httplib2) (1.12.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/tljh/user/lib/python3.7/site-packages (from google-auth-oauthlib) (1.3.0)
# Requirement already satisfied: protobuf<4.0.0dev,>=3.15.0 in /opt/tljh/user/lib/python3.7/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.17.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /opt/tljh/user/lib/python3.7/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2.22.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /mnt/HC_Volume_18315164/home-jupyter/jupyter-p-rudenko/.local/lib/python3.7/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (1.56.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/tljh/user/lib/python3.7/site-packages (from google-auth<3.0.0dev,>=1.16.0->google-api-python-client) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/tljh/user/lib/python3.7/site-packages (from google-auth<3.0.0dev,>=1.16.0->google-api-python-client) (4.1.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/tljh/user/lib/python3.7/site-packages (from google-auth<3.0.0dev,>=1.16.0->google-api-python-client) (4.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/tljh/user/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=1.16.0->google-api-python-client) (0.4.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/tljh/user/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/tljh/user/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/tljh/user/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (2020.4.5.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/tljh/user/lib/python3.7/site-packages (from requests<3.0.0dev,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-api-python-client) (1.24.2)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/tljh/user/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.1.0)
# WARNING: You are using pip version 21.2.4; however, version 22.1.2 is available.
# You should consider upgrading via the '/opt/tljh/user/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
AIzaSyAmP5CdhRBdI3AoejLWUERza825Hrs2u80

# %%
vim 'credentials.json'
# Out:
#   File "<ipython-input-8-e8154bc25648>", line 1
#     vim 'credentials.json'
#                          ^
# SyntaxError: invalid syntax

# %%
from __future__ import print_function

import os.path

from google.auth.transport.requests import Request
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# If modifying these scopes, delete the file token.json.
SCOPES = ['https://www.googleapis.com/auth/spreadsheets.readonly']

# The ID and range of a sample spreadsheet.
SAMPLE_SPREADSHEET_ID = '1BxiMVs0XRA5nFMdKvBdBZjgmUUqptlbs74OgvE2upms'
SAMPLE_RANGE_NAME = 'Class Data!A2:E'


def main():
    """Shows basic usage of the Sheets API.
    Prints values from a sample spreadsheet.
    """
    creds = None
    # The file token.json stores the user's access and refresh tokens, and is
    # created automatically when the authorization flow completes for the first
    # time.
    if os.path.exists('token.json'):
        creds = Credentials.from_authorized_user_file('token.json', SCOPES)
    # If there are no (valid) credentials available, let the user log in.
    if not creds or not creds.valid:
        if creds and creds.expired and creds.refresh_token:
            creds.refresh(Request())
        else:
            flow = InstalledAppFlow.from_client_secrets_file(
                'credentials.json', SCOPES)
            creds = flow.run_local_server(port=0)
        # Save the credentials for the next run
        with open('token.json', 'w') as token:
            token.write(creds.to_json())

    try:
        service = build('sheets', 'v4', credentials=creds)

        # Call the Sheets API
        sheet = service.spreadsheets()
        result = sheet.values().get(spreadsheetId=SAMPLE_SPREADSHEET_ID,
                                    range=SAMPLE_RANGE_NAME).execute()
        values = result.get('values', [])

        if not values:
            print('No data found.')
            return

        print('Name, Major:')
        for row in values:
            # Print columns A and E, which correspond to indices 0 and 4.
            print('%s, %s' % (row[0], row[4]))
    except HttpError as err:
        print(err)


if __name__ == '__main__':
    main()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-6d7bb5b0c9c7> in <module>
#      61
#      62 if __name__ == '__main__':
# ---> 63     main()
#
# <ipython-input-9-6d7bb5b0c9c7> in main()
#      33         else:
#      34             flow = InstalledAppFlow.from_client_secrets_file(
# ---> 35                 'credentials.json', SCOPES)
#      36             creds = flow.run_local_server(port=0)
#      37         # Save the credentials for the next run
#
# /opt/tljh/user/lib/python3.7/site-packages/google_auth_oauthlib/flow.py in from_client_secrets_file(cls, client_secrets_file, scopes, **kwargs)
#     197             client_config = json.load(json_file)
#     198
# --> 199         return cls.from_client_config(client_config, scopes=scopes, **kwargs)
#     200
#     201     @property
#
# /opt/tljh/user/lib/python3.7/site-packages/google_auth_oauthlib/flow.py in from_client_config(cls, client_config, scopes, **kwargs)
#     157         else:
#     158             raise ValueError(
# --> 159                 'Client secrets must be for a web or installed app.')
#     160
#     161         # these args cannot be passed to requests_oauthlib.OAuth2Session
#
# ValueError: Client secrets must be for a web or installed app.
